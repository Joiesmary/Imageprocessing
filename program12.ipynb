# %%
import cv2
import matplotlib.image as mping
import matplotlib.pyplot as plt
img1=cv2.imread('download11.png')
img2=cv2.imread('down.png')
fimg1=img1+img2
plt.imshow(fimg1)
plt.show()
cv2.imwrite('output.png',fimg1)
fimg2=img1-img2
plt.imshow(fimg2)
plt.show()
cv2.imwrite('output.png',fimg2)
fimg3=img1*img2
plt.imshow(fimg3)
plt.show()
cv2.imwrite('output.png',fimg3)
fimg4=img1/img2
plt.imshow(fimg4)
plt.show()
cv2.imwrite('output.png',fimg4)
# Out:
# C:\Users\Central Computer Lab\AppData\Local\Temp\ipykernel_7180\4059084450.py:18: RuntimeWarning: invalid value encountered in true_divide
#   fimg4=img1/img2
# True
